# %%
import scipy
import csv
import os
import glob
import numpy, scipy.misc
from PIL import Image
# from IPython.display import Image

class SingleGntImage(object):
    def __init__(self, f):
        self.f = f

    def read_gb_label(self):
        label_gb = self.f.read(2)

        # check garbage label
        if label_gb.encode('hex') is 'ff':
            return True, None
        # normal label        
        else:
            label_uft8 = label_gb.decode('gb18030').encode('utf-8')
            return False, label_uft8

    def read_special_hex(self, length):
        num_hex_str = ""
        
        # switch the order of bits
        for i in range(length):
            hex_2b = self.f.read(1)
            num_hex_str = hex_2b + num_hex_str

        return int(num_hex_str.encode('hex'), 16)

    def read_single_image(self):
        
        # zero-one value
        max_value = 255.0
        margin = 4

        # try to read next single image
        try:
            self.next_length = self.read_special_hex(4)
        except ValueError:
            print("Notice: end of file")
            return None, None, None, None, True

        # read the chinese utf-8 label
        self.is_garbage, self.label = self.read_gb_label()

        # read image width and height and do assert
        self.width = self.read_special_hex(2)
        self.height = self.read_special_hex(2)
        assert self.next_length == self.width * self.height + 10

        # read image matrix
        image_matrix_list = []
        for i in range(self.height):
            row = []
            for j in range(self.width):
                row.append(self.read_special_hex(1))

            image_matrix_list.append(row)

        # convert to numpy ndarray with size of 40 * 40 and add margin of 4
        self.image_matrix_numpy = \
            scipy.misc.imresize(numpy.array(image_matrix_list), \
            size=(40, 40)) / max_value
        self.image_matrix_numpy = numpy.lib.pad(self.image_matrix_numpy, \
            margin, self.padwithones)
        return self.label, self.image_matrix_numpy, \
            self.width, self.height, False

    def padwithones(self, vector, pad_width, iaxis, kwargs):
        vector[:pad_width[0]] = 1.0
        vector[-pad_width[1]:] = 1.0
        return vector

class ReadGntFile(object):
    def __init__(self):
        pass

    def find_file(self):
        file_extend = ".gnt"
        self.file_list = []

        # get all gnt files in the dir
        
#         dir_path = os.path.join(os.path.split(__file__)[0], "..", "data")
        
        dir_path = 'C:\Users\daniel\Documents\AImaster\kanjiconfusion\competition_POT\dataset'
        
        for file_name in glob.glob(os.path.join(dir_path, '*.gnt')):
            self.file_list.append(file_name)

        return self.file_list

    def show_image(self):
        end_of_image = False
        count_file = 0
        count_im = 0
        width_list = []
        height_list = []
        
        labels = []

        #open all gnt files
        for i, file_name in enumerate(self.file_list):
            
            temp_labels = []
            end_of_image = False
            count_file = count_file + 1
            count_single = 0
            with open(file_name, 'rb') as f:
                while not end_of_image:
                    count_single = count_single + 1
                    this_single_image = SingleGntImage(f)

                    # get the pixel matrix of a single image
                    label, pixel_matrix, width, height, end_of_image = \
                        this_single_image.read_single_image()
                    
                    width_list.append(width)
                    height_list.append(height)
#                     print(count_single, label, \
#                         width, height, numpy.shape(pixel_matrix))
                    temp_labels.append(label)

                    self.save_image(pixel_matrix, label, count_file, count_single)
#                     if count_single >= 10:
#                       end_of_image = True
            
            print ("End of file #%i") % (count_file)
            labels.append(temp_labels)
        with open("output.csv", "wb") as f:
            writer = csv.writer(f)
            writer.writerows(labels)

    def save_image(self, matrix, label, count_file, count_single):
        im = Image.fromarray(matrix)
        name = ("offline_competition_data/im-%s_%i.tiff") % (count_file, count_single)
        im.save(name)

def display_char_image():
    gnt_file = ReadGntFile()
    file_list = gnt_file.find_file()
#     print(file_list)
    gnt_file.show_image()
#     Image(file_list[0])


if __name__ == '__main__':
    display_char_image()
# Out:
# End of file #1
# ['\xe5\x95\x8a', '\xe9\x98\xbf', '\xe5\x9f\x83', '\xe6\x8c\xa8', '\xe5\x93\x8e', '\xe5\x94\x89', '\xe5\x93\x80', '\xe7\x9a\x91', '\xe7\x99\x8c', '\xe8\x94\xbc']
# End of file #2
# ['\xe5\x95\x8a', '\xe9\x98\xbf', '\xe5\x9f\x83', '\xe6\x8c\xa8', '\xe5\x93\x8e', '\xe5\x94\x89', '\xe5\x93\x80', '\xe7\x9a\x91', '\xe7\x99\x8c', '\xe8\x94\xbc']
# End of file #3
# ['\xe5\x95\x8a', '\xe9\x98\xbf', '\xe5\x9f\x83', '\xe6\x8c\xa8', '\xe5\x93\x8e', '\xe5\x94\x89', '\xe5\x93\x80', '\xe7\x9a\x91', '\xe7\x99\x8c', '\xe8\x94\xbc']
# End of file #4
# ['\xe5\x95\x8a', '\xe9\x98\xbf', '\xe5\x9f\x83', '\xe6\x8c\xa8', '\xe5\x93\x8e', '\xe5\x94\x89', '\xe5\x93\x80', '\xe7\x9a\x91', '\xe7\x99\x8c', '\xe8\x94\xbc']
# End of file #5
# ['\xe5\x95\x8a', '\xe9\x98\xbf', '\xe5\x9f\x83', '\xe6\x8c\xa8', '\xe5\x93\x8e', '\xe5\x94\x89', '\xe5\x93\x80', '\xe7\x9a\x91', '\xe7\x99\x8c', '\xe8\x94\xbc']
# End of file #6
# ['\xe5\x95\x8a', '\xe9\x98\xbf', '\xe5\x9f\x83', '\xe6\x8c\xa8', '\xe5\x93\x8e', '\xe5\x94\x89', '\xe5\x93\x80', '\xe7\x9a\x91', '\xe7\x99\x8c', '\xe8\x94\xbc']
# End of file #7
# ['\xe5\x95\x8a', '\xe9\x98\xbf', '\xe5\x9f\x83', '\xe6\x8c\xa8', '\xe5\x93\x8e', '\xe5\x94\x89', '\xe5\x93\x80', '\xe7\x9a\x91', '\xe7\x99\x8c', '\xe8\x94\xbc']
# End of file #8
# ['\xe5\x95\x8a', '\xe9\x98\xbf', '\xe5\x9f\x83', '\xe6\x8c\xa8', '\xe5\x93\x8e', '\xe5\x94\x89', '\xe5\x93\x80', '\xe7\x9a\x91', '\xe7\x99\x8c', '\xe8\x94\xbc']
# End of file #9
# ['\xe5\x95\x8a', '\xe9\x98\xbf', '\xe5\x9f\x83', '\xe6\x8c\xa8', '\xe5\x93\x8e', '\xe5\x94\x89', '\xe5\x93\x80', '\xe7\x9a\x91', '\xe7\x99\x8c', '\xe8\x94\xbc']
# End of file #10
# ['\xe5\x95\x8a', '\xe9\x98\xbf', '\xe5\x9f\x83', '\xe6\x8c\xa8', '\xe5\x93\x8e', '\xe5\x94\x89', '\xe5\x93\x80', '\xe7\x9a\x91', '\xe7\x99\x8c', '\xe8\x94\xbc']
# End of file #11
# ['\xe8\xba\xb2', '\xe6\x9c\xb5', '\xe8\xb7\xba', '\xe8\x88\xb5', '\xe5\x89\x81', '\xe6\x83\xb0', '\xe5\xa0\x95', '\xe8\x9b\xbe', '\xe5\xb3\xa8', '\xe9\xb9\x85']
# End of file #12
# ['\xe8\xba\xb2', '\xe6\x9c\xb5', '\xe8\xb7\xba', '\xe8\x88\xb5', '\xe5\x89\x81', '\xe6\x83\xb0', '\xe5\xa0\x95', '\xe8\x9b\xbe', '\xe5\xb3\xa8', '\xe9\xb9\x85']
# End of file #13
# ['\xe8\xba\xb2', '\xe6\x9c\xb5', '\xe8\xb7\xba', '\xe8\x88\xb5', '\xe5\x89\x81', '\xe6\x83\xb0', '\xe5\xa0\x95', '\xe8\x9b\xbe', '\xe5\xb3\xa8', '\xe9\xb9\x85']
# End of file #14
# ['\xe8\xba\xb2', '\xe6\x9c\xb5', '\xe8\xb7\xba', '\xe8\x88\xb5', '\xe5\x89\x81', '\xe6\x83\xb0', '\xe5\xa0\x95', '\xe8\x9b\xbe', '\xe5\xb3\xa8', '\xe9\xb9\x85']
# End of file #15
# ['\xe8\xba\xb2', '\xe6\x9c\xb5', '\xe8\xb7\xba', '\xe8\x88\xb5', '\xe5\x89\x81', '\xe6\x83\xb0', '\xe5\xa0\x95', '\xe8\x9b\xbe', '\xe5\xb3\xa8', '\xe9\xb9\x85']
# End of file #16
# ['\xe8\xba\xb2', '\xe6\x9c\xb5', '\xe8\xb7\xba', '\xe8\x88\xb5', '\xe5\x89\x81', '\xe6\x83\xb0', '\xe5\xa0\x95', '\xe8\x9b\xbe', '\xe5\xb3\xa8', '\xe9\xb9\x85']
# End of file #17
# ['\xe8\xba\xb2', '\xe6\x9c\xb5', '\xe8\xb7\xba', '\xe8\x88\xb5', '\xe5\x89\x81', '\xe6\x83\xb0', '\xe5\xa0\x95', '\xe8\x9b\xbe', '\xe5\xb3\xa8', '\xe9\xb9\x85']
# End of file #18
# ['\xe8\xba\xb2', '\xe6\x9c\xb5', '\xe8\xb7\xba', '\xe8\x88\xb5', '\xe5\x89\x81', '\xe6\x83\xb0', '\xe5\xa0\x95', '\xe8\x9b\xbe', '\xe5\xb3\xa8', '\xe9\xb9\x85']
# End of file #19
# ['\xe8\xba\xb2', '\xe6\x9c\xb5', '\xe8\xb7\xba', '\xe8\x88\xb5', '\xe5\x89\x81', '\xe6\x83\xb0', '\xe5\xa0\x95', '\xe8\x9b\xbe', '\xe5\xb3\xa8', '\xe9\xb9\x85']
# End of file #20
# ['\xe8\xba\xb2', '\xe6\x9c\xb5', '\xe8\xb7\xba', '\xe8\x88\xb5', '\xe5\x89\x81', '\xe6\x83\xb0', '\xe5\xa0\x95', '\xe8\x9b\xbe', '\xe5\xb3\xa8', '\xe9\xb9\x85']
# End of file #21
# ['\xe8\xa7\x92', '\xe9\xa5\xba', '\xe7\xbc\xb4', '\xe7\xbb\x9e', '\xe5\x89\xbf', '\xe6\x95\x99', '\xe9\x85\xb5', '\xe8\xbd\xbf', '\xe8\xbe\x83', '\xe5\x8f\xab']
# End of file #22
# ['\xe8\xa7\x92', '\xe9\xa5\xba', '\xe7\xbc\xb4', '\xe7\xbb\x9e', '\xe5\x89\xbf', '\xe6\x95\x99', '\xe9\x85\xb5', '\xe8\xbd\xbf', '\xe8\xbe\x83', '\xe5\x8f\xab']
# End of file #23
# ['\xe8\xa7\x92', '\xe9\xa5\xba', '\xe7\xbc\xb4', '\xe7\xbb\x9e', '\xe5\x89\xbf', '\xe6\x95\x99', '\xe9\x85\xb5', '\xe8\xbd\xbf', '\xe8\xbe\x83', '\xe5\x8f\xab']
# End of file #24
# ['\xe8\xa7\x92', '\xe9\xa5\xba', '\xe7\xbc\xb4', '\xe7\xbb\x9e', '\xe5\x89\xbf', '\xe6\x95\x99', '\xe9\x85\xb5', '\xe8\xbd\xbf', '\xe8\xbe\x83', '\xe5\x8f\xab']
# End of file #25
# ['\xe8\xa7\x92', '\xe9\xa5\xba', '\xe7\xbc\xb4', '\xe7\xbb\x9e', '\xe5\x89\xbf', '\xe6\x95\x99', '\xe9\x85\xb5', '\xe8\xbd\xbf', '\xe8\xbe\x83', '\xe5\x8f\xab']
# End of file #26
# ['\xe8\xa7\x92', '\xe9\xa5\xba', '\xe7\xbc\xb4', '\xe7\xbb\x9e', '\xe5\x89\xbf', '\xe6\x95\x99', '\xe9\x85\xb5', '\xe8\xbd\xbf', '\xe8\xbe\x83', '\xe5\x8f\xab']
# End of file #27
# ['\xe8\xa7\x92', '\xe9\xa5\xba', '\xe7\xbc\xb4', '\xe7\xbb\x9e', '\xe5\x89\xbf', '\xe6\x95\x99', '\xe9\x85\xb5', '\xe8\xbd\xbf', '\xe8\xbe\x83', '\xe5\x8f\xab']
# End of file #28
# ['\xe8\xa7\x92', '\xe9\xa5\xba', '\xe7\xbc\xb4', '\xe7\xbb\x9e', '\xe5\x89\xbf', '\xe6\x95\x99', '\xe9\x85\xb5', '\xe8\xbd\xbf', '\xe8\xbe\x83', '\xe5\x8f\xab']
# End of file #29
# ['\xe8\xa7\x92', '\xe9\xa5\xba', '\xe7\xbc\xb4', '\xe7\xbb\x9e', '\xe5\x89\xbf', '\xe6\x95\x99', '\xe9\x85\xb5', '\xe8\xbd\xbf', '\xe8\xbe\x83', '\xe5\x8f\xab']
# End of file #30
# ['\xe8\xa7\x92', '\xe9\xa5\xba', '\xe7\xbc\xb4', '\xe7\xbb\x9e', '\xe5\x89\xbf', '\xe6\x95\x99', '\xe9\x85\xb5', '\xe8\xbd\xbf', '\xe8\xbe\x83', '\xe5\x8f\xab']
# End of file #31
# ['\xe5\xa2\xa8', '\xe9\xbb\x98', '\xe6\xb2\xab', '\xe6\xbc\xa0', '\xe5\xaf\x9e', '\xe9\x99\x8c', '\xe8\xb0\x8b', '\xe7\x89\x9f', '\xe6\x9f\x90', '\xe6\x8b\x87']
# End of file #32
# ['\xe5\xa2\xa8', '\xe9\xbb\x98', '\xe6\xb2\xab', '\xe6\xbc\xa0', '\xe5\xaf\x9e', '\xe9\x99\x8c', '\xe8\xb0\x8b', '\xe7\x89\x9f', '\xe6\x9f\x90', '\xe6\x8b\x87']
# End of file #33
# ['\xe5\xa2\xa8', '\xe9\xbb\x98', '\xe6\xb2\xab', '\xe6\xbc\xa0', '\xe5\xaf\x9e', '\xe9\x99\x8c', '\xe8\xb0\x8b', '\xe7\x89\x9f', '\xe6\x9f\x90', '\xe6\x8b\x87']
# End of file #34
# ['\xe5\xa2\xa8', '\xe9\xbb\x98', '\xe6\xb2\xab', '\xe6\xbc\xa0', '\xe5\xaf\x9e', '\xe9\x99\x8c', '\xe8\xb0\x8b', '\xe7\x89\x9f', '\xe6\x9f\x90', '\xe6\x8b\x87']
# End of file #35
# ['\xe5\xa2\xa8', '\xe9\xbb\x98', '\xe6\xb2\xab', '\xe6\xbc\xa0', '\xe5\xaf\x9e', '\xe9\x99\x8c', '\xe8\xb0\x8b', '\xe7\x89\x9f', '\xe6\x9f\x90', '\xe6\x8b\x87']
# End of file #36
# ['\xe5\xa2\xa8', '\xe9\xbb\x98', '\xe6\xb2\xab', '\xe6\xbc\xa0', '\xe5\xaf\x9e', '\xe9\x99\x8c', '\xe8\xb0\x8b', '\xe7\x89\x9f', '\xe6\x9f\x90', '\xe6\x8b\x87']
# End of file #37
# ['\xe5\xa2\xa8', '\xe9\xbb\x98', '\xe6\xb2\xab', '\xe6\xbc\xa0', '\xe5\xaf\x9e', '\xe9\x99\x8c', '\xe8\xb0\x8b', '\xe7\x89\x9f', '\xe6\x9f\x90', '\xe6\x8b\x87']
# End of file #38
# ['\xe5\xa2\xa8', '\xe9\xbb\x98', '\xe6\xb2\xab', '\xe6\xbc\xa0', '\xe5\xaf\x9e', '\xe9\x99\x8c', '\xe8\xb0\x8b', '\xe7\x89\x9f', '\xe6\x9f\x90', '\xe6\x8b\x87']
# End of file #39
# ['\xe5\xa2\xa8', '\xe9\xbb\x98', '\xe6\xb2\xab', '\xe6\xbc\xa0', '\xe5\xaf\x9e', '\xe9\x99\x8c', '\xe8\xb0\x8b', '\xe7\x89\x9f', '\xe6\x9f\x90', '\xe6\x8b\x87']
# End of file #40
# ['\xe5\xa2\xa8', '\xe9\xbb\x98', '\xe6\xb2\xab', '\xe6\xbc\xa0', '\xe5\xaf\x9e', '\xe9\x99\x8c', '\xe8\xb0\x8b', '\xe7\x89\x9f', '\xe6\x9f\x90', '\xe6\x8b\x87']
# End of file #41
# ['\xe8\x96\xaf', '\xe6\x9a\x91', '\xe6\x9b\x99', '\xe7\xbd\xb2', '\xe8\x9c\x80', '\xe9\xbb\x8d', '\xe9\xbc\xa0', '\xe5\xb1\x9e', '\xe6\x9c\xaf', '\xe8\xbf\xb0']
# End of file #42
# ['\xe8\x96\xaf', '\xe6\x9a\x91', '\xe6\x9b\x99', '\xe7\xbd\xb2', '\xe8\x9c\x80', '\xe9\xbc\xa0', '\xe5\xb1\x9e', '\xe6\x9c\xaf', '\xe8\xbf\xb0', '\xe6\xa0\x91']
# End of file #43
# ['\xe8\x96\xaf', '\xe6\x9a\x91', '\xe6\x9b\x99', '\xe7\xbd\xb2', '\xe8\x9c\x80', '\xe9\xbb\x8d', '\xe9\xbc\xa0', '\xe5\xb1\x9e', '\xe6\x9c\xaf', '\xe8\xbf\xb0']
# End of file #44
# ['\xe8\x96\xaf', '\xe6\x9a\x91', '\xe6\x9b\x99', '\xe7\xbd\xb2', '\xe8\x9c\x80', '\xe9\xbb\x8d', '\xe9\xbc\xa0', '\xe5\xb1\x9e', '\xe6\x9c\xaf', '\xe8\xbf\xb0']
# End of file #45
# ['\xe8\x96\xaf', '\xe6\x9a\x91', '\xe6\x9b\x99', '\xe7\xbd\xb2', '\xe8\x9c\x80', '\xe9\xbb\x8d', '\xe9\xbc\xa0', '\xe5\xb1\x9e', '\xe6\x9c\xaf', '\xe8\xbf\xb0']
# End of file #46
# ['\xe8\x96\xaf', '\xe6\x9a\x91', '\xe6\x9b\x99', '\xe7\xbd\xb2', '\xe8\x9c\x80', '\xe9\xbb\x8d', '\xe9\xbc\xa0', '\xe5\xb1\x9e', '\xe6\x9c\xaf', '\xe8\xbf\xb0']
# End of file #47
# ['\xe8\x96\xaf', '\xe6\x9a\x91', '\xe6\x9b\x99', '\xe7\xbd\xb2', '\xe8\x9c\x80', '\xe9\xbb\x8d', '\xe9\xbc\xa0', '\xe5\xb1\x9e', '\xe6\x9c\xaf', '\xe8\xbf\xb0']
# End of file #48
# ['\xe8\x96\xaf', '\xe6\x9a\x91', '\xe6\x9b\x99', '\xe7\xbd\xb2', '\xe8\x9c\x80', '\xe9\xbb\x8d', '\xe9\xbc\xa0', '\xe5\xb1\x9e', '\xe6\x9c\xaf', '\xe8\xbf\xb0']
# End of file #49
# ['\xe8\x96\xaf', '\xe6\x9a\x91', '\xe6\x9b\x99', '\xe7\xbd\xb2', '\xe8\x9c\x80', '\xe9\xbb\x8d', '\xe9\xbc\xa0', '\xe5\xb1\x9e', '\xe6\x9c\xaf', '\xe8\xbf\xb0']
# End of file #50
# ['\xe8\x96\xaf', '\xe6\x9a\x91', '\xe6\x9b\x99', '\xe7\xbd\xb2', '\xe8\x9c\x80', '\xe9\xbb\x8d', '\xe9\xbc\xa0', '\xe5\xb1\x9e', '\xe6\x9c\xaf', '\xe8\xbf\xb0']
# End of file #51
# ['\xe8\x9c\x92', '\xe5\xb2\xa9', '\xe5\xbb\xb6', '\xe8\xa8\x80', '\xe9\xa2\x9c', '\xe9\x98\x8e', '\xe7\x82\x8e', '\xe6\xb2\xbf', '\xe5\xa5\x84', '\xe6\x8e\xa9']
# End of file #52
# ['\xe8\x9c\x92', '\xe5\xb2\xa9', '\xe5\xbb\xb6', '\xe8\xa8\x80', '\xe9\xa2\x9c', '\xe9\x98\x8e', '\xe7\x82\x8e', '\xe6\xb2\xbf', '\xe5\xa5\x84', '\xe6\x8e\xa9']
# End of file #53
# ['\xe8\x9c\x92', '\xe5\xb2\xa9', '\xe5\xbb\xb6', '\xe8\xa8\x80', '\xe9\xa2\x9c', '\xe9\x98\x8e', '\xe7\x82\x8e', '\xe6\xb2\xbf', '\xe5\xa5\x84', '\xe6\x8e\xa9']
# End of file #54
# ['\xe8\x9c\x92', '\xe5\xb2\xa9', '\xe5\xbb\xb6', '\xe8\xa8\x80', '\xe9\xa2\x9c', '\xe9\x98\x8e', '\xe7\x82\x8e', '\xe6\xb2\xbf', '\xe5\xa5\x84', '\xe6\x8e\xa9']
# End of file #55
# ['\xe8\x9c\x92', '\xe5\xb2\xa9', '\xe5\xbb\xb6', '\xe8\xa8\x80', '\xe9\xa2\x9c', '\xe9\x98\x8e', '\xe7\x82\x8e', '\xe6\xb2\xbf', '\xe5\xa5\x84', '\xe6\x8e\xa9']
# End of file #56
# ['\xe8\x9c\x92', '\xe5\xb2\xa9', '\xe5\xbb\xb6', '\xe8\xa8\x80', '\xe9\xa2\x9c', '\xe9\x98\x8e', '\xe7\x82\x8e', '\xe6\xb2\xbf', '\xe5\xa5\x84', '\xe6\x8e\xa9']
# End of file #57
# ['\xe8\x9c\x92', '\xe5\xb2\xa9', '\xe5\xbb\xb6', '\xe8\xa8\x80', '\xe9\xa2\x9c', '\xe9\x98\x8e', '\xe7\x82\x8e', '\xe6\xb2\xbf', '\xe5\xa5\x84', '\xe6\x8e\xa9']
# End of file #58
# ['\xe8\x9c\x92', '\xe5\xb2\xa9', '\xe5\xbb\xb6', '\xe8\xa8\x80', '\xe9\xa2\x9c', '\xe9\x98\x8e', '\xe7\x82\x8e', '\xe6\xb2\xbf', '\xe5\xa5\x84', '\xe6\x8e\xa9']
# End of file #59
# ['\xe8\x9c\x92', '\xe5\xb2\xa9', '\xe5\xbb\xb6', '\xe8\xa8\x80', '\xe9\xa2\x9c', '\xe9\x98\x8e', '\xe7\x82\x8e', '\xe6\xb2\xbf', '\xe5\xa5\x84', '\xe6\x8e\xa9']
# End of file #60
# ['\xe8\x9c\x92', '\xe5\xb2\xa9', '\xe5\xbb\xb6', '\xe8\xa8\x80', '\xe9\xa2\x9c', '\xe9\x98\x8e', '\xe7\x82\x8e', '\xe6\xb2\xbf', '\xe5\xa5\x84', '\xe6\x8e\xa9']
